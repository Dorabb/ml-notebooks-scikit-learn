# %%
from sklearn.preprocessing import StandardScaler
X = [[0, 15],
     [1, -10]]
#scale data according to computed scaling values
#"ColumnTranfer" is designed to use cases
StandardScaler().fit(X).transform(X)
