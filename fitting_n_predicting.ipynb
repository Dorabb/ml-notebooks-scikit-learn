# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
X = [[ 1, 2, 3],  # two samples/oberavations and three features/variables
     [ 11, 12, 13]]
y = [0, 1] # classes of each sample or obseravtions
clf.fit(X, y)
